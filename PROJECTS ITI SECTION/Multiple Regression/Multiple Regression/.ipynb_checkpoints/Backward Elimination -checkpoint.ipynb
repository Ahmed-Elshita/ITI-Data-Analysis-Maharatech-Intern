# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, 4]

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X = pd.get_dummies(X,drop_first=True)

# %%
X.head()
print(X.shape)
# Out:
# (50, 5)

# %%
# Splitting the dataset into the Training set and Test set
from  sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)
print(regressor.score(X_test,y_test))
# Out:
# 0.9347068473282423

# %%
# Building the optimal model using Backward Elimination
import statsmodels.formula.api as sm
X_train=X_train.values
y_train=y_train.values
X_train = np.append(arr = np.ones((40, 1)).astype(int), values = X_train, axis = 1)
df=pd.DataFrame(X_train)
df.head()
# Out:
#      0         1          2          3    4    5
# 0  1.0  55493.95  103057.49  214634.81  1.0  0.0
# 1  1.0  46014.02   85047.44  205517.64  0.0  1.0
# 2  1.0  75328.87  144135.98  134050.07  1.0  0.0
# 3  1.0  46426.07  157693.92  210797.67  0.0  0.0
# 4  1.0  91749.16  114175.79  294919.57  1.0  0.0

# %%
X_train_opt = X_train[:, [0, 1, 2, 3, 4, 5]]
df = pd.DataFrame(X_train_opt[:,:] ,y_train) 
df.head()
# Out:
#              0         1          2          3    4    5
# 96778.92   1.0  55493.95  103057.49  214634.81  1.0  0.0
# 96479.51   1.0  46014.02   85047.44  205517.64  0.0  1.0
# 105733.54  1.0  75328.87  144135.98  134050.07  1.0  0.0
# 96712.80   1.0  46426.07  157693.92  210797.67  0.0  0.0
# 124266.90  1.0  91749.16  114175.79  294919.57  1.0  0.0

# %%
regressor_OLS =sm.ols('y_train~X_train_opt', data=df).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                y_train   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     129.7
# Date:                Thu, 21 Jul 2022   Prob (F-statistic):           3.91e-21
# Time:                        22:14:46   Log-Likelihood:                -421.10
# No. Observations:                  40   AIC:                             854.2
# Df Residuals:                      34   BIC:                             864.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_train_opt = X_train[:, [0, 1, 3, 4,5]]
df = pd.DataFrame(X_train_opt[:,:] ,y_train) 
df.head()
regressor_OLS =sm.ols('y_train~X_train_opt', data=df).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                y_train   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     165.6
# Date:                Thu, 21 Jul 2022   Prob (F-statistic):           3.19e-22
# Time:                        22:14:46   Log-Likelihood:                -421.24
# No. Observations:                  40   AIC:                             852.5
# Df Residuals:                      35   BIC:                             860.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_train_opt = X_train[:, [0,1,3,4]]
df = pd.DataFrame(X_train_opt[:,:] ,y_train) 
df.head()
regressor_OLS =sm.ols('y_train~X_train_opt', data=df).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                y_train   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     227.0
# Date:                Thu, 21 Jul 2022   Prob (F-statistic):           1.96e-23
# Time:                        22:14:46   Log-Likelihood:                -421.25
# No. Observations:                  40   AIC:                             850.5
# Df Residuals:                      36   BIC:                             857.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_train_opt = X_train[:, [0,1,3]]
df = pd.DataFrame(X_train_opt[:,:] ,y_train) 
df.head()
regressor_OLS =sm.ols('y_train~X_train_opt', data=df).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                y_train   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     349.0
# Date:                Thu, 21 Jul 2022   Prob (F-statistic):           9.65e-25
# Time:                        22:14:46   Log-Likelihood:                -421.30
# No. Observations:                  40   AIC:                             848.6
# Df Residuals:                      37   BIC:                             853.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_train_opt = X_train[:, [0,1]]
df = pd.DataFrame(X_train_opt[:,:] ,y_train) 
df.head()
regressor_OLS =sm.ols('y_train~X_train_opt', data=df).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                y_train   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     652.4
# Date:                Thu, 21 Jul 2022   Prob (F-statistic):           1.56e-25
# Time:                        22:14:46   Log-Likelihood:                -423.09
# No. Observations:                  40   AIC:                             850.2
# Df Residuals:                      38   BIC:                             853.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_test =X_test.values
y_test =y_test.values
regressor.fit(X_train[:, [1,3]], y_train)
print(regressor.score(X_test[:, [0,2]],y_test))
# Out:
# 0.9474386447268488
